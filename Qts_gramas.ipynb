# %% [markdown]
# # Calculando a quantidade necessaria de oxigenio para formar 40 gramas de Metano
#
# * 2g de H e 4g de O > formam 8g de metano
# * 6g de H e 12g de O > formam 16g de metano
#
#
# | Hidrogenio | Oxgineio | Metano |
# |------------|----------|--------|
# | 2g         | 4g       | 8g     |
# | 6g         | 12g      | 16g    |
# | 10g        | ????     | 40g    |
#
# Quantos gramas de oxigenio e necessario para formar 40 gramas de Metano?

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

x = np.array([[2], [4]])
y = np.array([[6], [12]])

ox = np.array([10]).reshape((-1, 1))

model = LinearRegression().fit(x, y) 
y_pred = model.predict([[10]])

print('Gramas de oxigenio:', y_pred)
# Out:
# Predicted response: [[30.]]
